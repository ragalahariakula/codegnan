# %%
import requests
import bs4

# %%
from bs4 import BeautifulSoup

# %%
url='https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city'

# %%
data=requests.get(url)
data
# Out:
# <Response [200]>

# %%
e = data.text
type(e)
# Out:
# str

# %%
soup=BeautifulSoup(data.text,'html')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <title>
#    Property for Sale in Vijayawada | 1222+ Vijayawada Properties for sale
#   </title>
#   <meta content="Search 1222+ Properties for sale in Vijayawada on Makaan.com. Find ✓310+ New Projects for sale. ✓229+ Flats/Apartments. ✓111+ Houses/Villas. Visit Now !" name="description"/>
#   <meta content="Buy Vijayawada Properties, Residential Property for sale in Vijayawada, Property for sale in Vijayawada, Vijayawada Property Sale" name="keywords"/>
#   <meta content="#fff" id="themeColor" name="theme-color"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="55ce01b3ca93c05fd5a41439a23dd0d9" name="p:domain_verify"/>
#   <meta content="155462194517712" name="fb:pages"/>
#   <meta content="India" name="country"/>
#   <meta content="website" name="og:type"/>
#   <meta content="Makaan.com" name="og:site_name"/>
# ...

# %%
#Extract indiviudal entries -->property name
soup.find('div',attrs={'class':'title-line'}).text
# Out:
# '3 BHK Apartment'

# %%
soup.find('span',attrs={'itemprop':'addressLocality'}).text
# Out:
# 'Poranki'

# %%
soup.find('div',attrs={'data-type':'price-link'}).text.strip()
# Out:
# '55.5 L'

# %%
soup.find('td',attrs={'class':'size'}).text.strip()
# Out:
# '1587'

# %%
soup.find('td',attrs={'class':'lbl rate'}).text
# Out:
# '3,497 / sq ft'

# %%
soup.find('td',attrs={'class':'val'}).text
# Out:
# 'Ready to move'

# %%
soup.find('span',attrs={'itemprop':'name'}).text
# Out:
# 'home'

# %%
soup.find('a',attrs={'class':'seller-name'}).text
# Out:
# 'seller'

# %%
soup.find('li',attrs={'class':'keypoint',
                     'title':'Bathrooms'}).text
# Out:
# '3 Bathrooms'

# %% [markdown]
# To extract entire page data

# %%
a = soup.find_all('div',attrs={'class':'title-line'})
print(len(a))
for i in a:
    print(i.text)
# Out:
# 20
# 3 BHK Apartment
# 2 BHK Apartment
# 2 BHK Independent House
# 3 BHK Apartment
# 3 BHK Apartment
# 3 BHK Apartment
# 2 BHK Apartment in Hycon Elite
# 3 BHK Independent Floor
# 3 BHK Independent Floor
# 2 BHK Independent House
# 6 BHK Independent House
# Residential Plot in Harivillu Fortune Legendary
# Residential Plot
# Residential Plot
# 3 BHK Apartment in Pooja Tree Storey
# 3 BHK Apartment in Sri Naga Sun Rise Enclave
# 2 BHK Independent House
# 3 BHK Apartment in Pooja Tree Storey
# 2 BHK Independent House
# 1 BHK Independent House

# %%
a = soup.find_all('div',attrs={'class':'title-line'})
b=[]
for i in a:
    b.append(i.text)
print(len(b))
print(b)
# Out:
# 20
# ['3 BHK Apartment', '2 BHK Apartment', '2 BHK Independent House', '3 BHK Apartment', '3 BHK Apartment', '3 BHK Apartment', '2 BHK Apartment in Hycon Elite', '3 BHK Independent Floor', '3 BHK Independent Floor', '2 BHK Independent House', '6 BHK Independent House', 'Residential Plot in Harivillu Fortune Legendary', 'Residential Plot', 'Residential Plot', '3 BHK Apartment in Pooja Tree Storey', '3 BHK Apartment in Sri Naga Sun Rise Enclave', '2 BHK Independent House', '3 BHK Apartment in Pooja Tree Storey', '2 BHK Independent House', '1 BHK Independent House']

# %% [markdown]
# optimization -->List Comprehension [exprsn for var in collection/func]

# %%
a = soup.find_all('div',attrs={'class':'title-line'})
prop_name = [i.text for i in a]
print(prop_name)
print(len(prop_name))
# Out:
# ['3 BHK Apartment', '2 BHK Apartment', '2 BHK Independent House', '3 BHK Apartment', '3 BHK Apartment', '3 BHK Apartment', '2 BHK Apartment in Hycon Elite', '3 BHK Independent Floor', '3 BHK Independent Floor', '2 BHK Independent House', '6 BHK Independent House', 'Residential Plot in Harivillu Fortune Legendary', 'Residential Plot', 'Residential Plot', '3 BHK Apartment in Pooja Tree Storey', '3 BHK Apartment in Sri Naga Sun Rise Enclave', '2 BHK Independent House', '3 BHK Apartment in Pooja Tree Storey', '2 BHK Independent House', '1 BHK Independent House']
# 20

# %%
b = soup.find_all('span',attrs={'itemprop':'addressLocality'})
loctn = [i.text for i in b]
print(loctn)
print(len(loctn))
# Out:
# ['Poranki', 'Poranki', 'Kankipadu', 'Gollapudi', 'Gannavaram', 'Ramavarapadu', 'Poranki', 'Gunadala', 'Vidhyadharpuram', 'Kanuru', 'Penamaluru', 'Kankipadu', 'Poranki', 'Kankipadu', 'Benz Circle', 'Gannavaram', 'Payakapuram', 'Benz Circle', 'Gannavaram', 'Rajarajeswari Peta']
# 20

# %%
c = soup.find_all('div',attrs={'data-type':'price-link'})
price = [i.text.strip() for i in c]
print(price)
print(len(price))
# Out:
# ['55.5 L', '48 L', '50 L', '89 L', '59.86 L', '65 L', '40 L', '56 L', '95 L', '48 L', '1.1 Cr', '16.83 L', '33 L', '20 L', '1.66 Cr', '74 L', '56 L', '1.66 Cr', '57.05 L', '37.18 L']
# 20

# %%
d = soup.find_all('td',attrs={'class':'size'})
area = [i.text.strip() for i in d]
print(area)
print(len(area))
# Out:
# ['1587', '1450', '1290', '2062', '1663', '2000', '1200', '1500', '1600', '1150', '3700', '1782', '1800', '1500', '2317', '1560', '1000', '2317', '1100', '648']
# 20

# %%
e = soup.find_all('td',attrs={'class':'lbl rate'})
prc_sft = [i.text for i in e]
print(prc_sft)
print(len(prc_sft))
# Out:
# ['3,497 / sq ft', '3,310 / sq ft', '3,875 / sq ft', '4,316 / sq ft', '3,600 / sq ft', '3,250 / sq ft', '3,333 / sq ft', '3,733 / sq ft', '5,937 / sq ft', '4,173 / sq ft', '2,972 / sq ft', '944 / sq ft', '1,833 / sq ft', '1,333 / sq ft', '7,200 / sq ft', '4,743 / sq ft', '5,600 / sq ft', '7,200 / sq ft', '5,186 / sq ft', '5,737 / sq ft']
# 20

# %%
f = soup.find_all('td',attrs={'class':'val'})
status = [i.text for i in f]
print(status)
print(len(status))
# Out:
# ['Ready to move', 'Ready to move', 'Under Construction', 'Ready to move', 'Ready to move', 'Ready to move', 'Ready to move', 'Ready to move', 'Under Construction', 'Under Construction', 'Ready to move', 'Resale', 'Resale', 'Resale', 'Under Construction', 'Ready to move', 'Ready to move', 'Under Construction', 'Under Construction', 'Ready to move']
# 20

# %%
g = soup.find_all('a',attrs={'class':'seller-name'})
b_name = [i.text for i in g]
print(b_name)
print(len(b_name))
# Out:
# ['seller', 'seller', 'seller', 'seller', 'seller', 'seller', 'seller', 'seller', 'seller', 'seller', 'seller', 'seller', 'seller', 'seller', 'Dial To Property', 'PV Infra pvt LTD', 'Sri Sai Ram Real Estate', 'Dial To Property', 'Dial to Property', '4closure']
# 20

# %%
h = soup.find_all('li',attrs={'class':'keypoint',
                     'title':'Bathrooms'})
n = [i.text for i in h]
print(n)
print(len(n))
# Out:
# ['3 Bathrooms', '2 Bathrooms', '2 Bathrooms', '3 Bathrooms', '3 Bathrooms', '3 Bathrooms', '2 Bathrooms', '3 Bathrooms', '3 Bathrooms', '2 Bathrooms', '7 Bathrooms', '3 Bathrooms', '3 Bathrooms', '2 Bathrooms', '3 Bathrooms', '2 Bathrooms', '2 Bathrooms']
# 17

# %%
#As we have missing values in above listsings we will map a logic to fill the missing data
#Extract the main tag -->ul
b = soup.find_all('ul',attrs = {'class':'listing-details'})
j = [i.text for i in b]
print(j)
#you will give a specific condition
# Out:
# ['3 BathroomsResale West facing', '2 BathroomsResale ', '2 BathroomsResale NorthEast facing', '3 BathroomsResale ', '3 BathroomsResale East facing', '3 - 4 years old3 BathroomsResale ', '2 BathroomsResale ', '3 BathroomsResale ', '3 BathroomsResale West facing', '2 BathroomsResale East facing', '6 - 7 years old7 BathroomsResale ', '1 - 2 years old', '1 open sidesWest facing', '6 - 7 years old', '3 BathroomsNew East facing', '2 - 3 years old3 BathroomsNew ', '5 - 6 years old2 BathroomsNew ', '3 BathroomsNew East facing', '2 BathroomsNew West facing', '6 - 7 years old2 BathroomsResale ']

# %%
b = soup.find_all('ul',attrs = {'class':'listing-details'})
bath_info = []
for i in b:
    if i.find('li',attrs={'class':'keypoint',
                     'title':'Bathrooms'}) is None:
        bath_info.append("Not mentioned")
    else:
        bath_info.append(i.find('li',attrs={'class':'keypoint',
                     'title':'Bathrooms'}).text)
print(bath_info)
print(len(bath_info))
# Out:
# ['3 Bathrooms', '2 Bathrooms', '2 Bathrooms', '3 Bathrooms', '3 Bathrooms', '3 Bathrooms', '2 Bathrooms', '3 Bathrooms', '3 Bathrooms', '2 Bathrooms', '7 Bathrooms', 'Not mentioned', 'Not mentioned', 'Not mentioned', '3 Bathrooms', '3 Bathrooms', '2 Bathrooms', '3 Bathrooms', '2 Bathrooms', '2 Bathrooms']
# 20

# %%
#Finally save the data in .csv file (dataframe creation)
import pandas as pd
data = pd.DataFrame({'Prop_Name':prop_name,'Builder':b_name,'Location':loctn,
                     'Price':price,'Area':area,
                    'Prc_Sqft':prc_sft,'Status':status,'Bathrooms':bath_info})
data
# Out:
#                                           Prop_Name                  Builder  \
# 0                                   3 BHK Apartment                   seller
# 1                                   2 BHK Apartment                   seller
# 2                           2 BHK Independent House                   seller
# 3                                   3 BHK Apartment                   seller
# 4                                   3 BHK Apartment                   seller
# 5                                   3 BHK Apartment                   seller
# 6                    2 BHK Apartment in Hycon Elite                   seller
# 7                           3 BHK Independent Floor                   seller
# 8                           3 BHK Independent Floor                   seller
# 9                           2 BHK Independent House                   seller
# 10                          6 BHK Independent House                   seller
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Prop_Name  20 non-null     object
#  1   Builder    20 non-null     object
#  2   Location   20 non-null     object
#  3   Price      20 non-null     object
#  4   Area       20 non-null     object
#  5   Prc_Sqft   20 non-null     object
#  6   Status     20 non-null     object
#  7   Bathrooms  20 non-null     object
# dtypes: object(8)
# memory usage: 1.4+ KB

# %%
data.to_csv("Plots_Vijayawada.csv")

# %%
#Scraping content from multiple pages
base_url = "https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page="
for i in range(1,11):
    print(base_url+str(i))
# Out:
# https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page=1
# https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page=2
# https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page=3
# https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page=4
# https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page=5
# https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page=6
# https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page=7
# https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page=8
# https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page=9
# https://www.makaan.com/vijayawada-residential-property/buy-property-in-vijayawada-city?page=10

# %%
import time
from IPython.display import clear_output

base_url = "https://www.makaan.com/hyderabad-residential-property/buy-property-in-hyderabad-city?page="

owner = []
no_bhk = []
locality = []
price = []
area_sqft = []
con_status = []

#create empty lists to store the data
builder_names = []
for i in range(1,63):
    url = base_url+str(i)
    
    print(f'Scraping Info from the page {i}')
    clear_output(wait=True)
    
    #we will pause for 5 sec
    time.sleep(5)
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'html')
    
    #builders info
    b = soup.find_all('a',attrs={'class':'seller-name'})
    for i in b:
        builder_names.append(i.text)
        
    #owner info
    own = soup.find_all('span',attrs={'class' : 'seller-type'})
    for o in own:
        owner.append(o.text)

    #number of bhk
    bh = soup.find_all('a',attrs={'class' : 'typelink'})
    for b in bh:
        no_bhk.append(b.span.text)
  
    #locality
    loc = soup.find_all('span',attrs={'itemprop' : 'addressLocality'})
    for l in loc:
        locality.append(l.text)
    
    #price
    prc = soup.find_all('div',attrs={'data-type' : 'price-link'})
    for p in prc:
        price.append(p.text)
    
    #area
    ar = soup.find_all('td',attrs={'class': 'size'})
    for a in ar:
        area_sqft.append(a.text)
    
    #construction status
    stat = soup.find_all('td',attrs={'class': 'val'})
    for s in stat:
        con_status.append(s.text)
# Out:
# Scraping Info from the page 62

# %%
print(len(owner),
len(no_bhk),
len(locality),
len(price),
len(area_sqft),
len(con_status))
# Out:
# 1240 1240 1240 1240 1240 1240

# %%
data=pd.DataFrame({'owner':owner,
'no of bhk':no_bhk,
'locality':locality,
'price':price,
'area_sqft':area_sqft,
'con_status':con_status})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   owner       1240 non-null   object
#  1   no of bhk   1240 non-null   object
#  2   locality    1240 non-null   object
#  3   price       1240 non-null   object
#  4   area_sqft   1240 non-null   object
#  5   con_status  1240 non-null   object
# dtypes: object(6)
# memory usage: 58.2+ KB

# %%
data.to_csv("Plots_Vijayawada.csv")
